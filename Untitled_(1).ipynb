# %%
import openai
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-390a346bb18c> in <cell line: 1>()
# ----> 1 import openai
#
# ModuleNotFoundError: No module named 'openai'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.1/212.1 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# ...

# %%
import openai

# %%
OPENAI_KEY="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"

# %%
openai.api_key=OPENAI_KEY

# %%
all_models=openai.models.list()

# %%
list(all_models)
# Out:
# [Model(id='curie-search-query', created=1651172509, object='model', owned_by='openai-dev'),
#  Model(id='babbage-search-query', created=1651172509, object='model', owned_by='openai-dev'),
#  Model(id='dall-e-3', created=1698785189, object='model', owned_by='system'),
#  Model(id='babbage-search-document', created=1651172510, object='model', owned_by='openai-dev'),
#  Model(id='dall-e-2', created=1698798177, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo-0301', created=1677649963, object='model', owned_by='openai'),
#  Model(id='davinci-search-query', created=1651172505, object='model', owned_by='openai-dev'),
#  Model(id='tts-1-hd-1106', created=1699053533, object='model', owned_by='system'),
#  Model(id='whisper-1', created=1677532384, object='model', owned_by='openai-internal'),
#  Model(id='tts-1-hd', created=1699046015, object='model', owned_by='system'),
#  Model(id='ada-search-document', created=1651172507, object='model', owned_by='openai-dev'),
# ...

# %%
import pandas as pd
pd.DataFrame(list(all_models),columns=["id","created","object","owned_by"])
# Out:
#                                    id                created           object  \
# 0            (id, curie-search-query)  (created, 1651172509)  (object, model)
# 1          (id, babbage-search-query)  (created, 1651172509)  (object, model)
# 2                      (id, dall-e-3)  (created, 1698785189)  (object, model)
# 3       (id, babbage-search-document)  (created, 1651172510)  (object, model)
# 4                      (id, dall-e-2)  (created, 1698798177)  (object, model)
# 5            (id, gpt-3.5-turbo-0301)  (created, 1677649963)  (object, model)
# 6          (id, davinci-search-query)  (created, 1651172505)  (object, model)
# 7                 (id, tts-1-hd-1106)  (created, 1699053533)  (object, model)
# 8                     (id, whisper-1)  (created, 1677532384)  (object, model)
# 9                      (id, tts-1-hd)  (created, 1699046015)  (object, model)
# 10          (id, ada-search-document)  (created, 1651172507)  (object, model)
# ...

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.0/798.0 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.3/48.3 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.2 MB/s eta 0:00:00
# ...

# %%
import langchain

# %%
product_description = "provide me product xyz orders in last 3 months in bar chart format"

# %%
prompt = f'''
Please extract the following information from the given text and return it as a JSON object:

Product
Time period
Data
Chart Type

This is the body of text to extract the information from:
{product_description}
'''

# %%
prompt
# Out:
# '\nPlease extract the following information from the given text and return it as a JSON object:\n\nProduct\nTime period\nData\nChart Type\n\nThis is the body of text to extract the information from:\nprovide me product xyz orders in last 3 months in bar chart format\n'

# %%
# This code is for v1 of the openai package: pypi.org/project/openai
from openai import OpenAI
client = OpenAI(api_key=OPENAI_KEY)

# %%
client

# %%
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
    {
      "role": "user",
      "content": prompt
    }
      ],
    temperature = 0
)

# %%
response
# Out:
# ChatCompletion(id='chatcmpl-8hgAXdKaYVQeYG6skQDyEckUsKG0p', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='{\n  "Product": "xyz",\n  "Time period": "last 3 months",\n  "Data": "orders",\n  "Chart Type": "bar chart"\n}', role='assistant', function_call=None, tool_calls=None))], created=1705420893, model='gpt-3.5-turbo-0613', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=36, prompt_tokens=62, total_tokens=98))

# %%
import json

# %%
output=response.choices[0].message.content
json.loads(output)
# Out:
# {'Product': 'xyz',
#  'Time period': 'last 3 months',
#  'Data': 'orders',
#  'Chart Type': 'bar chart'}

# %%
import sys
while True:
    product_description = input(f"Input Product Description:")
    prompt = f'''
    Please extract the following information from the given text and return it as a JSON object , if it containes more the more product or Time period , then store it into list and then return a JSON object:

    Product
    Time period
    Data
    Chart Type

    This is the body of text to extract the information from:
    {product_description}
    '''
    if product_description == 'exit':
        sys.exit()
    if product_description == '':
        continue
    print(prompt)
    response = client.chat.completions.create(model="gpt-3.5-turbo",messages=[{"role":"user","content":prompt}],temperature=0)
    output = output=response.choices[0].message.content
    temp = json.loads(output)
    print(temp)
# Out:
# Input Product Description: give product abc sales for last 8 months in bar chart get me in bar chart last 10 months of sales for product omc
#     Please extract the following information from the given text and return it as a JSON object , if it containes more the more product or Time period , then store it into list and then return a JSON object:
#
#     Product
#     Time period
#     Data
#     Chart Type
#
#     This is the body of text to extract the information from:
#     give product abc sales for last 8 months in bar chart get me in bar chart last 10 months of sales for product omc
#
# {'Product': ['abc', 'omc'], 'Time period': ['last 8 months', 'last 10 months'], 'Data': ['sales', 'sales'], 'Chart Type': ['bar chart', 'bar chart']}
# Input Product Description: provide me product xyz orders in last 3 months in bar chart format
# ...

# %%
import sys
while True:
    product_description = input(f"Input Product Description:")
    prompt = f'''
    Please extract the following information from the given text and return it as a JSON object :

    Product
    Time period
    Data
    Chart Type

    This is the body of text to extract the information from:
    {product_description}
    '''
    if product_description == 'exit':
        sys.exit()
    if product_description == '':
        continue
    print(prompt)
    response = client.chat.completions.create(model="gpt-3.5-turbo",messages=[{"role":"user","content":prompt}],temperature=0)
    output = output=response.choices[0].message.content
    temp = json.loads(output)
    print(temp)
# Out:
# Input Product Description: import sys while True:     product_description = input(f"Input Product Description:")     prompt = f'''     Please extract the following information from the given text and return it as a JSON object , if it containes more the more product or Time period , then store it into list and then return a JSON object:      Product     Time period     Data     Chart Type      This is the body of text to extract the information from:     {product_description}     '''     if product_description == 'exit':         sys.exit()     if product_description == '':         continue     print(prompt)     response = client.chat.completions.create(model="gpt-3.5-turbo",messages=[{"role":"user","content":prompt}],temperature=0)     output = output=response.choices[0].message.content     temp = json.loads(output)     print(temp)
#     Please extract the following information from the given text and return it as a JSON object :
#
#     Product
#     Time period
#     Data
# ...

# %%
import sys
json_data = {'Product': '',
                 'Time period': '',
                 'Data': '',
                 'Chart Type': ''}
data = json_data
df = pd.DataFrame([data])
while True:
    product_description = input(f"Input Product Description:")
    prompt = f'''
    Please extract the following information from the given text and return it as a JSON object :

    Product
    Time period
    Data
    Chart Type

    This is the body of text to extract the information from:
    {product_description}
    '''
    if product_description == 'exit':
        sys.exit()
    if product_description == '':
        continue
    print(prompt)
    response = client.chat.completions.create(model="gpt-3.5-turbo",messages=[{"role":"user","content":prompt}],temperature=0)
    output = output=response.choices[0].message.content
    json_data = json.loads(output)
    data = json_data
    new_data = pd.DataFrame([data])
    #new_data["query"] = [product_description]
    df = pd.concat([df,new_data],ignore_index=True)
    print(df)
else:
  df.to_csv('output.csv', index=False)
  print("\nFinal DataFrame has been stored in 'output.csv'")

# %%
df.to_csv('output.csv', index=False)
print("\nFinal DataFrame has been stored in 'output.csv'")

# %%
# implement the memory part of it !!

# %%
## now my goal is to store the query and its response in a data or csv sheet , so that , it will later get stored in a vector database and generate the output with that context

# %%
## Testing

# %%
import sys
json_data = {'Product': '',
                 'Time period': '',
                 'Data': '',
                 'Chart Type': ''}
data = json_data
df = pd.DataFrame([data])
while True:
    product_description = input(f"Input Product Description:")
    prompt = f'''
    Please extract the following information from the given text and return it as a JSON object :

    Product
    Time period
    Data
    Chart Type

    This is the body of text to extract the information from:
    {product_description}
    '''
    if product_description == 'exit':
        sys.exit()
    if product_description == '':
        continue
    print(prompt)
    response = client.chat.completions.create(model="gpt-3.5-turbo",messages=[{"role":"user","content":prompt}],temperature=0)
    output = output=response.choices[0].message.content
    json_data = json.loads(output)
    data = json_data
    new_data = pd.DataFrame([data])
    #new_data["query"] = [product_description]
    df = pd.concat([df,new_data],ignore_index=True)
    print(df)
else:
  df.to_csv('output.csv', index=False)
  print("\nFinal DataFrame has been stored in 'output.csv'")
# Out:
# Input Product Description:provide me product xyz orders in last 3 months in bar chart format
#
#     Please extract the following information from the given text and return it as a JSON object :
#
#     Product
#     Time period
#     Data
#     Chart Type
#
#     This is the body of text to extract the information from:
#     provide me product xyz orders in last 3 months in bar chart format
#
#   Product    Time period    Data Chart Type  \
# 0
# 1     xyz  last 3 months  orders  bar chart
#
#                                                query
# 0                                                NaN
# 1  provide me product xyz orders in last 3 months...
# Input Product Description:Show me last 4 months sale of product pqr as bar chart.
#
#     Please extract the following information from the given text and return it as a JSON object :
#
#     Product
#     Time period
#     Data
#     Chart Type
#
#     This is the body of text to extract the information from:
# ...

# %%
df
# Out:
#   Product    Time period    Data Chart Type  \
# 0
# 1     xyz  last 3 months  orders  bar chart
# 2     pqr  last 4 months    sale  bar chart
#
#                                                query
# 0                                                NaN
# 1  provide me product xyz orders in last 3 months...
# 2  Show me last 4 months sale of product pqr as b...

# %%
.df
# Out:
#   Product     Time period         Data    Chart Type
# 0
# 1    lmno  last 18 months        sales  violin chart
# 2     ppz  last 22 months  expenditure  violin chart
# 3     aab  last 56 months        sales     pie chart

# %%
df.to_csv('output.csv', index=False)
print("\nFinal DataFrame has been stored in 'output.csv'")
# Out:
# Final DataFrame has been stored in 'output.csv'

# %%
new_data
# Out:
#   Product     Time period   Data Chart Type
# 0     aab  last 56 months  sales  pie chart

# %%
import pandas as pd

# Existing DataFrame
existing_data = {'Product': ['xyz'],
                 'Time period': ['last 3 months'],
                 'Data': ['orders'],
                 'Chart Type': ['bar chart']}

df = pd.DataFrame(existing_data)

# Display the existing DataFrame
print("Existing DataFrame:")
print(df)

# Add an extra column
df['New Column'] = ['value_for_new_row']

# Display the updated DataFrame
print("\nUpdated DataFrame:")
print(df)
# Out:
# Existing DataFrame:
#   Product    Time period    Data Chart Type
# 0     xyz  last 3 months  orders  bar chart
#
# Updated DataFrame:
#   Product    Time period    Data Chart Type         New Column
# 0     xyz  last 3 months  orders  bar chart  value_for_new_row
